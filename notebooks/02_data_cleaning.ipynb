# %% [markdown]
# ## **Data Cleaning Summary**
#
# The dataset was cleaned to improve consistency, usability, and reliability for analysis. The following steps were performed:
#
# 1. **Column Name Standardization**
#    - All column names were converted to lowercase.
#    - Spaces were replaced with underscores to follow standard naming conventions.
#    - This ensures easier handling of columns in Python, SQL, and BI tools.
#
#
# 2. **Standardization of `item_fat_content` Values**
#    - The `item_fat_content` column contained inconsistent labels such as
#      `Regular`, `reg`, `Low Fat`, `low fat`, and `LF`.
#    - These values were standardized into two consistent categories:
#      **Regular** and **Low Fat**.
#
#
# 3. **Handling Missing Values in `item_weight`**
#    - The `item_weight` column contained missing values (~17% of rows).
#    - A two-level imputation strategy was applied:
#      - First, missing values were filled using the **median item weight for the same `item_identifier`**.
#      - Remaining missing values were filled using the **median item weight of the corresponding `item_type`**.
#    - This approach preserves item-level accuracy while providing a reasonable fallback.
#    - After imputation, no missing values remained in the `item_weight` column.
#
#
# 4. **Final Data Quality Check**
#    - The dataset contains no missing values in critical analytical columns.
#    - Categorical variables are consistent and standardized.
#    - The dataset is now suitable for exploratory data analysis, SQL-based analysis, and dashboard development.
#
# ---
#
# ### Cleaning Outcome
# After cleaning, the dataset is structured, consistent, and analysis-ready, closely reflecting real-world business data used in retail analytics workflows.

# %% [markdown]
# ## **Import Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Dataset Load**

# %%
data = pd.read_excel(r"C:\Users\rudra\OneDrive\Documents\GitHub\blinkit-end-to-end-data-analysis\data\raw\blinkit_grocery_data.xlsx")
df = data.copy()

# %%
df.head()
# Out:
#   Item Fat Content Item Identifier              Item Type  \
# 0          Regular           FDX32  Fruits and Vegetables
# 1          Low Fat           NCB42     Health and Hygiene
# 2          Regular           FDR28           Frozen Foods
# 3          Regular           FDL50                 Canned
# 4          Low Fat           DRI25            Soft Drinks
#
#    Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                       2012            OUT049               Tier 1
# 1                       2022            OUT018               Tier 3
# 2                       2016            OUT046               Tier 1
# 3                       2014            OUT013               Tier 3
# 4                       2015            OUT045               Tier 2
#
#   Outlet Size        Outlet Type  Item Visibility  Item Weight     Sales  \
# 0      Medium  Supermarket Type1         0.100014        15.10  145.4786
# 1      Medium  Supermarket Type2         0.008596        11.80  115.3492
# 2       Small  Supermarket Type1         0.025896        13.85  165.0210
# 3        High  Supermarket Type1         0.042278        12.15  126.5046
# 4       Small  Supermarket Type1         0.033970        19.60   55.1614
#
#    Rating
# 0     5.0
# 1     5.0
# 2     5.0
# 3     5.0
# 4     5.0

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# ### **1. Standardizing Column Name**

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df.sample(5)
# Out:
#      item_fat_content item_identifier           item_type  \
# 7325          Regular           DRB13         Soft Drinks
# 280           Low Fat           DRD60         Soft Drinks
# 6880          Low Fat           FDC04               Dairy
# 7158          Low Fat           FDD35       Starchy Foods
# 5180          Low Fat           NCK29  Health and Hygiene
#
#       outlet_establishment_year outlet_identifier outlet_location_type  \
# 7325                       2020            OUT017               Tier 2
# 280                        2017            OUT035               Tier 2
# 6880                       2015            OUT045               Tier 2
# 7158                       2020            OUT017               Tier 2
# 5180                       2012            OUT049               Tier 1
#
#      outlet_size        outlet_type  item_visibility  item_weight     sales  \
# 7325      Medium  Supermarket Type1         0.007084        6.115  191.1530
# 280        Small  Supermarket Type1         0.037225       15.700  182.4634
# 6880      Medium  Supermarket Type1         0.045077       15.600  241.3854
# 7158        High  Supermarket Type1         0.026011       12.150  119.1440
# 5180      Medium  Supermarket Type1         0.125965        5.615  124.7730
#
#       rating
# 7325     4.0
# 280      5.0
# 6880     4.0
# 7158     4.0
# 5180     3.1

# %% [markdown]
# ### **2. Fixing the Inonsistency in `item_fat_content` column**

# %%
df['item_fat_content'].unique()
# Out:
# array(['Regular', 'Low Fat', 'low fat', 'LF', 'reg'], dtype=object)

# %%
replace_map = {

    "reg" : "Regular",
    "low fat" : "Low Fat",
    "LF" : "Low Fat"
}

df['item_fat_content'] = df['item_fat_content'].replace(replace_map)

# %%
df['item_fat_content'].unique()
# Out:
# array(['Regular', 'Low Fat'], dtype=object)

# %%
df.sample(5)
# Out:
#      item_fat_content item_identifier              item_type  \
# 814           Low Fat           FDN20  Fruits and Vegetables
# 3217          Regular           FDQ48           Baking Goods
# 5326          Low Fat           FDS23                 Breads
# 4014          Low Fat           FDK27                   Meat
# 3709          Low Fat           FDS01                 Canned
#
#       outlet_establishment_year outlet_identifier outlet_location_type  \
# 814                        2020            OUT017               Tier 2
# 3217                       2017            OUT035               Tier 2
# 5326                       2017            OUT035               Tier 2
# 4014                       2017            OUT035               Tier 2
# 3709                       2022            OUT018               Tier 3
#
#      outlet_size        outlet_type  item_visibility  item_weight     sales  \
# 814        Small  Supermarket Type1         0.026330       19.350  169.2474
# 3217       Small  Supermarket Type1         0.034405       14.300   98.1726
# 5326       Small  Supermarket Type1         0.140862        4.635  126.4994
# 4014       Small  Supermarket Type1         0.008945       11.000  122.3756
# 3709      Medium  Supermarket Type2         0.017817       11.600  177.0686
#
#       rating
# 814      4.5
# 3217     4.0
# 5326     3.0
# 4014     3.9
# 3709     4.0

# %% [markdown]
# ### **3. Fixing Missing values in the `item_weight` column**

# %%
df['item_weight'].isnull().sum()
# Out:
# 1463

# %%
df['item_weight'] = df.groupby('item_identifier')['item_weight'].transform(lambda x: x.fillna(x.median()))

# %%
df['item_weight'].isnull().sum()
# Out:
# 4

# %%
df[df['item_weight'].isnull()]
# Out:
#      item_fat_content item_identifier     item_type  \
# 2046          Regular           FDN52  Frozen Foods
# 4582          Low Fat           FDK57   Snack Foods
# 6514          Regular           FDQ60  Baking Goods
# 8452          Regular           FDE52         Dairy
#
#       outlet_establishment_year outlet_identifier outlet_location_type  \
# 2046                       2018            OUT027               Tier 3
# 4582                       2018            OUT027               Tier 3
# 6514                       2018            OUT019               Tier 1
# 8452                       2018            OUT027               Tier 3
#
#      outlet_size        outlet_type  item_visibility  item_weight     sales  \
# 2046      Medium  Supermarket Type3         0.130933          NaN   86.9198
# 4582      Medium  Supermarket Type3         0.079904          NaN  120.0440
# 6514       Small      Grocery Store         0.191501          NaN  121.2098
# 8452      Medium  Supermarket Type3         0.029742          NaN   88.9514
#
#       rating
# 2046     4.2
# 4582     3.7
# 6514     4.0
# 8452     4.0

# %%
df ['item_weight'] = df.groupby('item_type')['item_weight'].transform(lambda x: x.fillna(x.median()))

# %%
df['item_weight'].isnull().sum()
# Out:
# 0

# %%
df.sample(5)
# Out:
#      item_fat_content item_identifier     item_type  \
# 7203          Regular           FDO52  Frozen Foods
# 6807          Regular           FDX33   Snack Foods
# 821           Regular           FDU50         Dairy
# 848           Low Fat           DRL60   Soft Drinks
# 559           Low Fat           FDK51         Dairy
#
#       outlet_establishment_year outlet_identifier outlet_location_type  \
# 7203                       2015            OUT045               Tier 2
# 6807                       2016            OUT046               Tier 1
# 821                        2015            OUT045               Tier 2
# 848                        2017            OUT035               Tier 2
# 559                        2011            OUT010               Tier 3
#
#      outlet_size        outlet_type  item_visibility  item_weight     sales  \
# 7203        High  Supermarket Type1         0.077321       11.600  169.3106
# 6807       Small  Supermarket Type1         0.117485        9.195  158.5578
# 821         High  Supermarket Type1         0.075323        5.750  116.3176
# 848        Small  Supermarket Type1         0.027054        8.520  151.5682
# 559       Medium      Grocery Store         0.008763       19.850  266.6884
#
#       rating
# 7203     4.0
# 6807     4.0
# 821      4.5
# 848      4.5
# 559      4.7

# %%
df.isnull().sum()
# Out:
# item_fat_content             0
# item_identifier              0
# item_type                    0
# outlet_establishment_year    0
# outlet_identifier            0
# outlet_location_type         0
# outlet_size                  0
# outlet_type                  0
# item_visibility              0
# item_weight                  0
# sales                        0
# rating                       0
# dtype: int64

# %%
## **Exporting Cleanned Data**

# %%
df.to_excel(r"C:\Users\rudra\OneDrive\Documents\GitHub\blinkit-end-to-end-data-analysis\data\processed\cleanned_blinkit_grocery_data.xlsx", index = False)
print("Data Exported Successfully.")
# Out:
# Data Exported Successfully.
