# %% [markdown]
# ### **📌Executive Summary**
#
# This analysis evaluates Blinkit’s sales performance using transactional data across product categories, outlet types, outlet sizes, and geographic tiers. The findings indicate that sales are primarily driven by product assortment and outlet strategy rather than individual numerical attributes such as item weight, visibility, or ratings. Core categories like Fruits & Vegetables and Snack Foods act as major revenue contributors, while Supermarket Type1 outlets dominate overall sales volume. Additionally, consistent performance across outlet sizes and city tiers highlights Blinkit’s strong operational standardization and demand stability beyond metro regions.

# %% [markdown]
# ### **📊 Key Business Insights**
#
# 1. **Category-driven demand dominates sales performance :**
# Sales are influenced more by product category and outlet strategy than by individual numerical factors such as ratings, visibility, or item weight.
#
# 3. **Fruits & Vegetables are the strongest revenue contributors :**
# This category consistently outperforms others across most outlet types, especially in Supermarket Type1 formats.
#
# 4. **Supermarket Type1 outlets act as the core revenue engine :**
# They generate the highest total sales across nearly all product categories, driven by higher transaction volume and customer footfall.
#
# 5. **Outlet size does not directly translate to higher sales :**
# Medium-sized outlets frequently outperform larger outlets, indicating that assortment and demand alignment matter more than physical size.
#
# 6. **Tier 2 and Tier 3 cities show strong and stable demand :**
# Sales performance remains consistent across geographic tiers, with Tier 3 locations hosting the largest number of outlets.
#
# 7. **Ratings and visibility act as quality filters, not growth drivers :**
# Poor ratings negatively impact sales, but higher ratings alone do not guarantee increased sales volume.

# %% [markdown]
# ### **🎯 Business Recommendations**
#
# 1. **Prioritize inventory and supply chain efficiency for core categories**
# Fruits & Vegetables and Snack Foods should receive focused attention due to their consistent contribution to total sales.
#
# 2. **Strengthen and optimize Supermarket Type1 outlets**
# These outlets should remain the primary focus for revenue optimization, pricing strategies, and promotional campaigns.
#
# 3. **Optimize product assortment by outlet size**
# Instead of expanding outlet size, Blinkit should tailor product mixes based on outlet format to maximize efficiency and sales.
#
# 4. **Continue expansion in Tier 2 and Tier 3 cities**
# Given the consistent demand patterns, non-metro regions present strong opportunities for scalable growth.
#
# 5. **Use customer ratings as a risk-control metric**
# Ratings should be monitored to prevent sales decline from poor-performing items, rather than being treated as a primary growth lever.
